# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
arr = np.random.normal(170,10,250)
plt.hist(arr)
plt.show()
# read file
file = pd.read_csv("real2.csv")
data = pd.DataFrame(file)
country = data["Country"]
data2 = np.array([20,30,40,10])
label = ["apple","orange","pomegranate","litchi"]
plt.pie(data2,labels=label,startangle=180,explode=[0.1,0.2,0.2,0.2],shadow=True,colors=["red","purple","green","black"])
plt.legend(title="fruits")
plt.show()
