# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
arr = np.random.uniform(10,100,20)
arr1 = np.random.uniform(10,100,20)
arr2 = np.random.uniform(10,100,20)
#plt.plot(arr,marker="d")
plt.plot(arr,"o-m",ms="6",mfc="yellow",mec="blue")
'''
fmt = marker|line|color
- Solid line
: Dashed Line
-. Dotted and Dashed Line
. Dashed Line
Shortchuts
marker
mec = marker edge color
mfc = marker face color
ms = marker size
'''
plt.plot(arr1,marker="o",mfc="red")
plt.show()
