# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
file = pd.read_csv("real2.csv")
data = pd.DataFrame(file)
arr = np.array([[3,7],[0,0],[1,8],[2,3],[10,20],[15,1]])
plt.plot(arr,marker="D")
plt.show()
